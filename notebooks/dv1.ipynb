# %%
# loading data and reading data
# Data Visualization

# %%
! wget https://raw.githubusercontent.com/mohammedashrafdagga/dataset_from_kaggle/main/dataset/fifa.csv
# Out:
# --2022-01-30 09:14:45--  https://raw.githubusercontent.com/mohammedashrafdagga/dataset_from_kaggle/main/dataset/fifa.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10403 (10K) [text/plain]
# Saving to: ‘fifa.csv’
#
# fifa.csv            100%[===================>]  10.16K  --.-KB/s    in 0s
#
# 2022-01-30 09:14:45 (94.8 MB/s) - ‘fifa.csv’ saved [10403/10403]

# %%
# import libaray to used
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fifa_data = pd.read_csv('fifa.csv', index_col="Date", parse_dates=True)
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data = fifa_data)

# %%
! wget https://raw.githubusercontent.com/mohammedashrafdagga/dataset_from_kaggle/main/dataset/spotify.csv
# Out:
# --2022-01-30 09:43:54--  https://raw.githubusercontent.com/mohammedashrafdagga/dataset_from_kaggle/main/dataset/spotify.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19851 (19K) [text/plain]
# Saving to: ‘spotify.csv’
#
# spotify.csv         100%[===================>]  19.39K  --.-KB/s    in 0s
#
# 2022-01-30 09:43:54 (103 MB/s) - ‘spotify.csv’ saved [19851/19851]

# %%
spotify_data = pd.read_csv('spotify.csv', index_col="Date", parse_dates=True)
spotify_data.head()
# Out:
#             Shape of You  Despacito  ...  HUMBLE.  Unforgettable
# Date                                 ...
# 2017-01-06      12287078        NaN  ...      NaN            NaN
# 2017-01-07      13190270        NaN  ...      NaN            NaN
# 2017-01-08      13099919        NaN  ...      NaN            NaN
# 2017-01-09      14506351        NaN  ...      NaN            NaN
# 2017-01-10      14275628        NaN  ...      NaN            NaN
#
# [5 rows x 5 columns]

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data = spotify_data)

# %%
plt.figure()

sns.lineplot(data = spotify_data['Shape of You'], label = 'Shape of You')
sns.lineplot(data = spotify_data['Despacito'], label = 'Despacito')

plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')
